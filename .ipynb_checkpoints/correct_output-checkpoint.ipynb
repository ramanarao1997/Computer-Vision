# %%
from Homography import Stitching

# %%
import matplotlib.pyplot as plt
from PIL import Image

st = Stitching()
# result = st.main("left1.jpg","right1.jpg")

# %%
from Homography import Stitching
import matplotlib.pyplot as plt
from PIL import Image

st = Stitching()

H = st.main("right1.jpg","left1.jpg")

im1 = st.readImage("right1.jpg")
im2 = st.readImage("left1.jpg")


output = st.finalImage(im1,im2,H)

plt.figure(figsize=(7,7))
plt.imshow(output)
# Out:
# Image successfully read...
# Image successfully read...
# Found keypoints in right1.jpg : 4196
# Found keypoints in left1.jpg : 5318
# Matching Features...
# 2603
# Corr size: 2603 NumInliers: 6 Max inliers: 6
# Corr size: 2603 NumInliers: 4 Max inliers: 6
# Corr size: 2603 NumInliers: 6 Max inliers: 6
# Corr size: 2603 NumInliers: 6 Max inliers: 6
# Corr size: 2603 NumInliers: 18 Max inliers: 18
# Corr size: 2603 NumInliers: 9 Max inliers: 18
# Corr size: 2603 NumInliers: 4 Max inliers: 18
# Corr size: 2603 NumInliers: 10 Max inliers: 18
# Corr size: 2603 NumInliers: 1148 Max inliers: 1148
# Corr size: 2603 NumInliers: 6 Max inliers: 1148
# Final homography: [[ 8.00014663e-01  3.89247635e-02  4.44451499e+02]
#  [-1.22291702e-01  9.29183589e-01  6.99749089e+01]
#  [-1.85275302e-04 -2.45455273e-05  1.00000000e+00]]
# Final inliers count: 1148
# Image successfully read...
# Image successfully read...
